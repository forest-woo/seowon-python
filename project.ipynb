# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
excel_files = ['2024년 3월 고용보험 통계표(수정).xlsx',
    '2024년 6월 고용보험 통계표.xlsx',
    '2024년 9월 고용보험 통계표.xlsx',
    '2024년 12월 고용보험 통계표.xlsx',
    '2025년 3월 고용보험 통계표.xlsx',
    '2025년 6월 고용보험 통계표.xlsx',
    '2025년 9월 고용보험 통계표.xlsx',
    '2025년 12월 고용보험 통계표.xlsx',
    '2026년 3월 고용보험 통계표.xlsx']
periods = ['2024.03', '2024.06', '2024.09', '2024.12', '2025.03', '2025.06', '2025.09', '2025.12', '2026.03']

# %%
df_list =[]

for i in excel_files:
    df = pd.read_excel(i, sheet_name= '2-3-2')
    df_list.append(df)

# %%
all_data = {}

for j in range(9):
    current_df = df_list[j]
    p = periods[j]

    j_idx = current_df[current_df.iloc[:,0].astype(str).str.contains("J.정보통신업")].index[0]
    k_idx = current_df[current_df.iloc[:, 0].astype(str).str.contains('K.금융')].index[0]

    sub_df = current_df.iloc[j_idx:k_idx].copy()

    for inx, row in sub_df.iterrows():
        subcat = row.iloc[2]
        val = row.iloc[3]

        # 값이 비어있지 않으면 실행
        if pd.notna(subcat):
            subcat_clean = str(subcat).strip() #이건 문자열 정리. 공백 제거
            val_clean = int(val) if pd.notna(val) else 0 #값 있으면 정수로 변환 없으면 0 넣기

            if subcat_clean not in all_data: #딕셔너리 생성 여부 확인 
                all_data[subcat_clean] = {}
            all_data[subcat_clean][p] = val_clean #예시 subcat_clean = "SW개발" p = "2024.03" val_clean = 52000 이면  all_data["SW개발"]["2024.03"] = 52000 이케 됨
      
    ''' 딕셔너리가 이렇게 됨 
    "SW개발": {
        "2024.03": 52000,
        "2024.06": 53000
    }  
    '''


            
final_df = pd.DataFrame(all_data).T
final_df.to_excel("정보통신업_소분류_최종시계열.xlsx")
print("최종 테이블 가공 및 엑셀 저장 완료!")
# Out:
# 최종 테이블 가공 및 엑셀 저장 완료!

# %%
df = pd.read_excel("정보통신업_소분류_최종시계열.xlsx")
df = df.rename(columns={'Unnamed: 0': '산업분류'})
df = df.set_index('산업분류')
df
# Out:
#                                         2024.03  2024.06  2024.09  2024.12  \
# 산업분류
# 581.서적, 잡지 및 기타 인쇄물 출판업                  111155   114905   115735   115879
# 582.소프트웨어 개발 및 공급업                        52307    51880    51260    50771
# 591.영화, 비디오물, 방송 프로그램 제작 및 배급업           447107   448691   449656   445909
# 592.오디오물 출판 및 원판 녹음업                      44810    45557    45026    43597
# 601.라디오 방송업                                2553     2536     2506     2514
# 602.텔레비전 방송업                               1666     1632     1626     1595
# 611.공영 우편업                                20700    20578    20534    20408
# 612.전기 통신업                                 5345     5340     5271     5452
# 620.컴퓨터 프로그래밍, 시스템 통합 및 관리업               65441    65087    64654    62009
# 631.자료 처리, 호스팅, 포털 및 기타 인터넷 정보 매개 서비스업    70981    71046    71524    71661
# 639.기타 정보 서비스업                            19733    19773    19632    19442
#
#                                         2025.03  2025.06  2025.09  2025.12  \
# 산업분류
# 581.서적, 잡지 및 기타 인쇄물 출판업                  114505   117685   119289   122204
# 582.소프트웨어 개발 및 공급업                        49993    49471    48954    48629
# 591.영화, 비디오물, 방송 프로그램 제작 및 배급업           444074   445835   449610   447606
# 592.오디오물 출판 및 원판 녹음업                      42619    42947    43210    42972
# 601.라디오 방송업                                2530     2575     2610     2512
# 602.텔레비전 방송업                               1572     1589     1584     1570
# 611.공영 우편업                                20184    20229    20287    20265
# 612.전기 통신업                                 5406     5423     5351     5414
# 620.컴퓨터 프로그래밍, 시스템 통합 및 관리업               61786    61522    61191    60322
# 631.자료 처리, 호스팅, 포털 및 기타 인터넷 정보 매개 서비스업    72261    72863    73210    73026
# 639.기타 정보 서비스업                            19355    19474    19738    19822
#
#                                         2026.03
# 산업분류
# 581.서적, 잡지 및 기타 인쇄물 출판업                   48221
# 582.소프트웨어 개발 및 공급업                       446112
# 591.영화, 비디오물, 방송 프로그램 제작 및 배급업            42317
# 592.오디오물 출판 및 원판 녹음업                       2482
# 601.라디오 방송업                                1549
# 602.텔레비전 방송업                              20250
# 611.공영 우편업                                 5369
# 612.전기 통신업                                59875
# 620.컴퓨터 프로그래밍, 시스템 통합 및 관리업               73687
# 631.자료 처리, 호스팅, 포털 및 기타 인터넷 정보 매개 서비스업    19585
# 639.기타 정보 서비스업                            61250

# %%
print(df.isnull().sum())
# Out:
# 2024.03    0
# 2024.06    0
# 2024.09    0
# 2024.12    0
# 2025.03    0
# 2025.06    0
# 2025.09    0
# 2025.12    0
# 2026.03    0
# dtype: int64

# %%
# 2025년 3월 대비 2026년 3월의 증감률 계산
growth = (df['2026.03'] - df['2025.03']) / df['2025.03'] * 100
plt.rcParams['font.family'] = 'AppleGothic'  
# 4분위수와 IQR 계산
Q1 = growth.quantile(0.25)
Q3 = growth.quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

plt.figure(figsize=(8,4))
plt.scatter(range(len(growth)), growth)
plt.axhline(upper, linestyle='--')
plt.axhline(lower, linestyle='--')
plt.ylabel('증감률 (%)')
plt.title('이상치 탐지')
plt.show()
# Out:
# /Users/choeulim/Desktop/대학교/2학년 전공/venv/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) AppleGothic.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#3월달 데이터 문제 발견 한 칸식 밀림 문제 이상치 발견 재배열
df.loc['581.서적, 잡지 및 기타 인쇄물 출판업','2026.03'] = 124176  
df.loc['582.소프트웨어 개발 및 공급업','2026.03'] = 48221
df.loc['591.영화, 비디오물, 방송 프로그램 제작 및 배급업','2026.03'] = 446112
df.loc['592.오디오물 출판 및 원판 녹음업','2026.03'] = 42317
df.loc['601.라디오 방송업','2026.03'] = 2482
df.loc['602.텔레비전 방송업', '2026.03'] = 1549
df.loc['611.공영 우편업', '2026.03'] = 20250 
df.loc['612.전기 통신업', '2026.03'] = 5369
df.loc['620.컴퓨터 프로그래밍, 시스템 통합 및 관리업', '2026.03'] = 59875
df.loc['631.자료 처리, 호스팅, 포털 및 기타 인터넷 정보 매개 서비스업', '2026.03'] = 73687
df.loc['639.기타 정보 서비스업', '2026.03'] = 19585

df
# Out:
#                                         2024.03  2024.06  2024.09  2024.12  \
# 산업분류
# 581.서적, 잡지 및 기타 인쇄물 출판업                  111155   114905   115735   115879
# 582.소프트웨어 개발 및 공급업                        52307    51880    51260    50771
# 591.영화, 비디오물, 방송 프로그램 제작 및 배급업           447107   448691   449656   445909
# 592.오디오물 출판 및 원판 녹음업                      44810    45557    45026    43597
# 601.라디오 방송업                                2553     2536     2506     2514
# 602.텔레비전 방송업                               1666     1632     1626     1595
# 611.공영 우편업                                20700    20578    20534    20408
# 612.전기 통신업                                 5345     5340     5271     5452
# 620.컴퓨터 프로그래밍, 시스템 통합 및 관리업               65441    65087    64654    62009
# 631.자료 처리, 호스팅, 포털 및 기타 인터넷 정보 매개 서비스업    70981    71046    71524    71661
# 639.기타 정보 서비스업                            19733    19773    19632    19442
#
#                                         2025.03  2025.06  2025.09  2025.12  \
# 산업분류
# 581.서적, 잡지 및 기타 인쇄물 출판업                  114505   117685   119289   122204
# 582.소프트웨어 개발 및 공급업                        49993    49471    48954    48629
# 591.영화, 비디오물, 방송 프로그램 제작 및 배급업           444074   445835   449610   447606
# 592.오디오물 출판 및 원판 녹음업                      42619    42947    43210    42972
# 601.라디오 방송업                                2530     2575     2610     2512
# 602.텔레비전 방송업                               1572     1589     1584     1570
# 611.공영 우편업                                20184    20229    20287    20265
# 612.전기 통신업                                 5406     5423     5351     5414
# 620.컴퓨터 프로그래밍, 시스템 통합 및 관리업               61786    61522    61191    60322
# 631.자료 처리, 호스팅, 포털 및 기타 인터넷 정보 매개 서비스업    72261    72863    73210    73026
# 639.기타 정보 서비스업                            19355    19474    19738    19822
#
#                                         2026.03
# 산업분류
# 581.서적, 잡지 및 기타 인쇄물 출판업                  124176
# 582.소프트웨어 개발 및 공급업                        48221
# 591.영화, 비디오물, 방송 프로그램 제작 및 배급업           446112
# 592.오디오물 출판 및 원판 녹음업                      42317
# 601.라디오 방송업                                2482
# 602.텔레비전 방송업                               1549
# 611.공영 우편업                                20250
# 612.전기 통신업                                 5369
# 620.컴퓨터 프로그래밍, 시스템 통합 및 관리업               59875
# 631.자료 처리, 호스팅, 포털 및 기타 인터넷 정보 매개 서비스업    73687
# 639.기타 정보 서비스업                            19585

# %%
#필요없는 로우 삭제

drop_targets = [
    '581.서적, 잡지 및 기타 인쇄물 출판업',
    '591.영화, 비디오물, 방송 프로그램 제작 및 배급업',
    '592.오디오물 출판 및 원판 녹음업',
    '601.라디오 방송업',
    '602.텔레비전 방송업',
    '611.공영 우편업',
    '612.전기 통신업',
    
]
df = df.drop(drop_targets, axis=0, errors='ignore')
df
# Out:
#                                         2024.03  2024.06  2024.09  2024.12  \
# 산업분류
# 582.소프트웨어 개발 및 공급업                        52307    51880    51260    50771
# 620.컴퓨터 프로그래밍, 시스템 통합 및 관리업               65441    65087    64654    62009
# 631.자료 처리, 호스팅, 포털 및 기타 인터넷 정보 매개 서비스업    70981    71046    71524    71661
# 639.기타 정보 서비스업                            19733    19773    19632    19442
#
#                                         2025.03  2025.06  2025.09  2025.12  \
# 산업분류
# 582.소프트웨어 개발 및 공급업                        49993    49471    48954    48629
# 620.컴퓨터 프로그래밍, 시스템 통합 및 관리업               61786    61522    61191    60322
# 631.자료 처리, 호스팅, 포털 및 기타 인터넷 정보 매개 서비스업    72261    72863    73210    73026
# 639.기타 정보 서비스업                            19355    19474    19738    19822
#
#                                         2026.03
# 산업분류
# 582.소프트웨어 개발 및 공급업                        48221
# 620.컴퓨터 프로그래밍, 시스템 통합 및 관리업               59875
# 631.자료 처리, 호스팅, 포털 및 기타 인터넷 정보 매개 서비스업    73687
# 639.기타 정보 서비스업                            19585

# %%
final_dataframe = pd.DataFrame(df).T
final_df.to_excel("데이터 완료.xlsx")

# %%
rename_dict = {

    '582.소프트웨어 개발 및 공급업':'SW 개발',

    '620.컴퓨터 프로그래밍, 시스템 통합 및 관리업':'웹 앱 개발 및 시스템 구축',

    '631.자료 처리, 호스팅, 포털 및 기타 인터넷 정보 매개 서비스업':'클라우드/데이터 인프라',

    '639.기타 정보 서비스업':'정보 서비스'

}

df = df.rename(index=rename_dict)

# %%
plt.figure(figsize=(12,6))

for col in df.index:
    plt.plot(df.columns,
             df.loc[col],
             marker='o',
             linewidth=2,
             label=col)

plt.title('업종별 취업자 수 변화', fontsize=18)
plt.xlabel('기간')
plt.ylabel('취업자 수')

plt.xticks(rotation=45)

plt.legend(
    bbox_to_anchor=(1.02, 1),
    loc='upper left'
)

plt.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %%
change_rate = df.pct_change(axis=1) * 100
change_rate = change_rate.fillna(0)

plt.figure(figsize=(10,5))

sns.heatmap(
    change_rate,
    annot=True,
    fmt='.1f',
    cmap='RdBu_r',
    center=0
)

plt.title('업종별 취업자 증감률(%)')

plt.tight_layout()
plt.show()
# Out:
# /Users/choeulim/Desktop/대학교/2학년 전공/venv/lib/python3.13/site-packages/seaborn/utils.py:61: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) AppleGothic.
#   fig.canvas.draw()
# /Users/choeulim/Desktop/대학교/2학년 전공/venv/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) AppleGothic.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
size = df['2026.03']

growth = (
    (df['2026.03'] - df['2024.03'])
    / df['2024.03']
) * 100

plt.figure(figsize=(10, 8))

plt.scatter(size, growth, s=150, alpha=0.8)

# 업종 이름 표시
for industry in df.index:
    plt.annotate(
        industry,
        (size[industry], growth[industry]),
        xytext=(5, 5),
        textcoords='offset points'
    )

# 평균선
plt.axvline(size.mean(), linestyle='--')
plt.axhline(growth.mean(), linestyle='--')

plt.xlabel('2026년 3월 고용보험 취득자 수')
plt.ylabel('성장률(%)')
plt.title('정보통신업 업종별 규모와 성장률')

plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['axes.unicode_minus'] = False
sns.set_context("talk")
change_rate = (
    (df['2026.03'] - df['2024.03'])
    / df['2024.03']
) * 100

change_rate = change_rate.sort_values()

# 색상
colors = ['tomato' if x < 0 else 'royalblue' for x in change_rate.values]

plt.figure(figsize=(11,6))

bars = plt.barh(
    change_rate.index,
    change_rate.values,
    color=colors,
    height=0.6
)

# 0 기준선
plt.axvline(0, color='gray', linewidth=1)

# 값 표시
for bar in bars:
    width = bar.get_width()

    plt.text(
        width + 0.2 if width > 0 else width - 0.5,
        bar.get_y() + bar.get_height()/2,
        f'{width:.1f}%',
        va='center',
        fontsize=10
    )

# 스타일
plt.title(
    'AI 시대 이후 정보통신업 취업자 변화율',
    fontsize=16,
    fontweight='bold'
)

plt.xlabel('변화율(%)', fontsize=12)

# 위/오른쪽 테두리 제거
plt.box(False)

# 연한 가로선
plt.grid(axis='x', linestyle='--', alpha=0.3)

plt.tight_layout()

plt.show()

# %%
total = df.sum(axis=0)
sns.set_context("talk")

plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['axes.unicode_minus'] = False

plt.figure(figsize=(10,5))
plt.plot(total.index, total.values, marker='o')


plt.title('정보통신업 전체 취업자 수 변화')
plt.xlabel('시점')
plt.ylabel('취업자 수')

plt.xticks(rotation=45)
plt.grid(True)

plt.show()

# %%
plt.figure(figsize=(10,5))

plt.plot(total.index,
         total.values,
         marker='o',
         linewidth=2)

z = np.polyfit(range(len(total)), total.values, 1)
p = np.poly1d(z)

plt.plot(
    total.index,
    p(range(len(total))),
    linestyle='--'
)

plt.title('전체 취업자 수 추세')
plt.xticks(rotation=45)

plt.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(14, 7))

ax[0].pie(
    df['2024.03'],
    labels=df.index,
    autopct='%1.1f%%',
    startangle=90
)
ax[0].set_title('2024년 3월 업종별 비중')

ax[1].pie(
    df['2026.03'],
    labels=df.index,
    autopct='%1.1f%%',
    startangle=90
)
ax[1].set_title('2026년 3월 업종별 비중')

plt.tight_layout()
plt.show()
